# %%
import pickle
import pandas as pd

# %%
with open('scores_output_validation.pickle', 'rb') as f:
    posts = pickle.load(f)

# %%
posts = pd.DataFrame(posts)
sofa = posts[posts['id'] == 'SOFÁ']

# %%
sofa[['link', 'ranking']].iloc[0]['link']
# Out:
# 'https://www.pinterest.es/pin/1134555331096361986/'

# %%
sofa[['link', 'ranking']].iloc[0]['ranking']
# Out:
# [('D083VA12', array([[0.6616653]], dtype=float32)),
#  ('D082VA12', array([[0.6616653]], dtype=float32)),
#  ('D081VA12', array([[0.65952104]], dtype=float32)),
#  ('D084VA12', array([[0.65952104]], dtype=float32)),
#  ('D080VA12', array([[0.65952104]], dtype=float32)),
#  ('AA7441J12', array([[0.6572423]], dtype=float32)),
#  ('AA8231J12', array([[0.64939106]], dtype=float32)),
#  ('AA8731J03', array([[0.6327395]], dtype=float32)),
#  ('AA8730J03', array([[0.63248885]], dtype=float32)),
#  ('AA3895PR12', array([[0.63089997]], dtype=float32))]

# %%
list(sofa['ranking'][0][1])
# Out:
# [[('D083VA12', array([[0.6616653]], dtype=float32)),
#   ('D082VA12', array([[0.6616653]], dtype=float32)),
#   ('D081VA12', array([[0.65952104]], dtype=float32)),
#   ('D084VA12', array([[0.65952104]], dtype=float32)),
#   ('D080VA12', array([[0.65952104]], dtype=float32)),
#   ('AA7441J12', array([[0.6572423]], dtype=float32)),
#   ('AA8231J12', array([[0.64939106]], dtype=float32)),
#   ('AA8731J03', array([[0.6327395]], dtype=float32)),
#   ('AA8730J03', array([[0.63248885]], dtype=float32)),
#   ('AA3895PR12', array([[0.63089997]], dtype=float32))],
#  [('AA8231J12', array([[0.5894005]], dtype=float32)),
#   ('AA3895PR12', array([[0.57133883]], dtype=float32)),
#   ('AA8730J03', array([[0.56980115]], dtype=float32)),
#   ('AA7960J39', array([[0.56948316]], dtype=float32)),
#   ('AA6771J39', array([[0.568981]], dtype=float32)),
#   ('AA8731J03', array([[0.56853324]], dtype=float32)),
#   ('AA6771J03', array([[0.56650424]], dtype=float32)),
# ...

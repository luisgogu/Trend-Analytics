# %%
import pandas as pd
import numpy as np
import unidecode
pd.set_option('display.max_rows', 400)
pd.set_option('display.max_columns', None)
import re

# %%
def drop_columns(df, columns):
    df.drop(columns,axis=1, inplace=True)
    return df

# %%
def get_furniture(row, furnitures):
    for f in furnitures:
        if f in row[1]:
            return f
    return 'otro'

# %%
df = pd.read_csv("descripcion_productos.csv", encoding='utf-8', sep=";")

# %%
# variables
columns = list(df.columns)
l = ['sku','descripcion','img_ambiente', 'img','Material de las patas',
     'Materiales','Construcción de la estructura','Forma del producto',
     'Material principal','Color principal','Año de publicación','Colores',
     'Estilo principal','Estancias']

# the order of the categories matter!!
furnitures = ['abridor', 'alfombra', 'almohada', 'ambientador', 'aparado',
       'aplique', 'armario', 'asiento', 'azucarero', 'bandeja', 'ban',
       'base', 'biombo', 'bolsa', 'bol', 'bombilla', 'book',
       'bote', 'botell', 'brazo', 'butaca', 'cabecero', 'caja',
       'cajon', 'cama', 'cambiador', 'canape', 'candelabro', 'cest', 'chaise',
       'cojin', 'colchoneta', 'colchon', 'colgador', 'consola', 'copa', 
       'corona', 'cortina', 'cuadro', 'cubo', 'delantal', 'escalera', 
       'escobilla', 'escritorio', 'espejo', 'estanteria', 'estante', 'estrella', 
       'figura', 'ganchos', 'guirnalda', 'hamaca', 'jabon', 'jarra', 'jarron', 
       'lampara', 'libreria', 'lienzo', 'llitera', 'macet', 'manta', 
       'mantel', 'marco', 'mecedora', 'mesa', 'mesita', 'modulo', 'mortero',
       'mueble', 'neceser', 'panel', 'pantalla', 'papel', 'perchero', 'pizarra', 
       'planta', 'plato', 'portacepillo', 'protector', 'puf', 'reloj',
       'reposacabezas', 'reposapies', 'revistero', 'rodillo', 'sabana',
       'salero', 'set', 'silla', 'sillon', 'sofacama', 'sofa',
       'somier', 'tabla', 'taburete', 'tapiceria', 'tapiz', 'taza',
       'tetera', 'tipi', 'toall', 'tumbona', 'vaso', 'vela', 'ventosas',
       'zapatero']

file = open("links.txt", "r", encoding='utf-8')
url = file.read().split('\n')
file.close()
    
for i,f in enumerate(url):
    url[i] = unidecode.unidecode(f.lower())
url.remove('chaiselongue')
url.remove('cesto')
url.remove('puff')

url = url + ['chaise', 'cest', 'puf']

# ban -> banco, banqueta
# macet -> macetas, macetero
# cest -> cesta, cestas, cestos
# toall -> toalla, toallas, toallero
# jarr -> jarra, jarron

# %%
# get columns of interest
for x in l:
    columns.remove(x)
df = drop_columns(df, columns)

# drop rows with a lot of NA
df.dropna(how='all', subset=['Material de las patas','Materiales','Construcción de la estructura',
                             'Forma del producto','Material principal','Color principal',
                             'Colores','Estilo principal','Estancias'], inplace=True)
df.dropna(subset=['descripcion'], inplace=True)

# lowercase
df['descripcion'] = df['descripcion'].str.lower()
df['descripcion'] = df.apply(lambda x: unidecode.unidecode(x[1]), axis=1)

# add label
df['id'] = df.apply(lambda x: get_furniture(x, furnitures), axis=1)

# Año de publicacion
df['Año de publicación'] = df['Año de publicación'].str.rstrip()

# %%
df_output = df[df['id'].isin(url)].reset_index(drop=True)

# %%
df_output[(df_output['id'] == 'silla') & (df_output['Color principal'] == 'Gris')][['sku','descripcion','img']]
# Out:
#              sku                                        descripcion  \
# 614      C423M01                                 alsie silla marron
# 630    C624FRJ15                     cust silla fr tela gris oscuro
# 634     C632JQ14  ralf silla madera natural tela acolchada gris ...
# 686   CC0252VD15                      alve silla tejido gris oscuro
# 688   CC0253VD15                            amira silla gris oscuro
# 697   CC0297BG15       runnie silla metal dorado tejido gris oscuro
# 699   CC0297LN15  runnie silla pana gruesa gris con patas de ace...
# 700   CC0297VD03                            runnie silla gris claro
# 727   CC0516JU03  freda silla terciopelo gris y patas de madera ...
# 769   CC0826PN15                 zahara silla metal negro pana gris
# 771   CC0826VD03                zahara silla metal negro tela gris
# 772   CC0826VD14           zahara silla metal negro tela gris claro
# 779    CC0854J15           ivonne silla metal negro terciopelo gris
# 789   CC0934BG15  silla konna de chenilla gris oscuro y patas de...
# 793   CC0934PK03  silla konna gris claro y patas de acero acabad...
# 795   CC0934PN14  silla konna pana gris y patas de acero acabado...
# 800    CC0966J03                                  canele silla gris
# 815   CC1084JU03                       yvette silla terciopelo gris
# 818   CC1084VD14                            yvette silla gris claro
# 819   CC1084VD15                           yvette silla gris oscuro
# 826   CC1152PK15                          eugenie silla gris oscuro
# 831   CC1167BG15                                   monna silla gris
# 834   CC1167PK03                             monna silla gris claro
# 876   CC1753VD03   silla madge gris claro y acero con acabado negro
# 877   CC1753VD15  silla madge gris oscuro y acero con acabado negro
# 913   CC1986AB15                            silla nadya gris oscuro
# 914   CC1987PN15  silla suanne de pana gris oscuro con patas de ...
# 918   CC2027PK03         silla anoha gris y metal con acabado negro
# 921    CC2093R14          silla plegable aidana de metal gris claro
# 922    CC2093R15         silla plegable aidana de metal gris oscuro
# 955   CC2213PK15  silla lumina gris oscuro y patas de acero con ...
# 964    CC3000J14  silla ciselia de borreguito gris claro y metal...
# 968   CC3003KY15  silla benilda gris oscuro, chapa de roble y ac...
# 984    CC5117J03  silla yanet de cuerda gris y patas de acero ga...
# 987   CC5165VD14                           silla giuilia gris claro
# 988   CC5165VD15                          silla giuilia gris oscuro
# 994    CC5184S03                                 silla hannia gris
# 1001  CC5212KY15  silla konna gris oscuro y patas de chapa de fr...
# 2134     C626J15                             davi silla gris oscuro
# 2196  CC0248VD03                              adam silla gris claro
# 2197  CC0248VD15                             adam silla gris oscuro
# 2198  CC0252VD03                       alve silla tejido gris claro
# 2203  CC0253UE85                                   amira silla gris
# 2204  CC0253VD03                             amira silla gris claro
# 2215  CC0297VD15                           runnie silla gris oscuro
# 2232   CC0502S03                                  whatts silla gris
# 2243  CC0518VA03  freda silla gris y patas de madera maciza de h...
# 2269  CC0826VD15          zahara silla metal negro tela gris oscuro
# 2283   CC0934J03  silla konna de terciopelo gris y patas de acer...
# 2284  CC0934LN15  silla konna de pana gruesa gris y patas de ace...
# 2286  CC0934PK15  silla konna gris oscuro y patas de acero acaba...
# 2298  CC0986PK03  rosie silla gris claro con patas de madera aca...
# 2299  CC0986PK15  rosie silla gris oscuro con patas de madera ac...
# 2301   CC1011J03  ellen silla gris claro cuerda y acero galvanizado
# 2307   CC1017J03                        yaren silla terciopelo gris
# 2329  CC1149PK03                             byre silla gris claro
# 2330  CC1149PK15                             byre silla gris oscuro
# 2332  CC1152PK03                           eugenie silla gris claro
# 2333  CC1154PK03                   jenna silla giratoria gris claro
# 2334  CC1154PK15                  jenna silla giratoria gris oscuro
# 2335  CC1155JU03                        fabia silla terciopelo gris
# 2344  CC1167PK15                            monna silla gris oscuro
# 2346  CC1169JU03                    silla laudelina terciopelo gris
# 2354   CC1222S02                                  silla quinby gris
# 2357  CC1225JU03                        delta silla terciopelo gris
# 2381  CC1760VD03  silla naiquen gris claro y acero con acabado n...
# 2382  CC1760VD15    silla naiquen gris oscuro y acero acabado negro
# 2383  CC1804PK03                           silla mahalia gris claro
# 2384  CC1804PK15                          silla mahalia gris oscuro
# 2402  CC1986AB14                             silla nadya gris claro
# 2403  CC1987GR02  silla suanne gris oscuro con patas de acero ac...
# 2404  CC1987LN15  silla suanne de pana gruesa gris con patas de ...
# 2412   CC2025J14  silla aniela de borreguito gris claro y metal ...
# 2436  CC2209JU03  silla marlene terciopelo gris patas acero acab...
# 2439  CC2211MN14  silla mael gris claro y patas de acero con aca...
# 2440  CC2211MN15  silla mael gris oscuro y patas de acero con ac...
# 2441  CC2212JU03  silla lumina terciopelo gris claro patas acero...
# 2489   CC5195S14            silla de exterior isabellini gris claro
# 2495   CC5212J14  silla konna de borreguito gris claro y patas d...
#
#                                                     img
# 614   http://intranet.juliagrup.com/GestionDocumenta...
# 630   http://intranet.juliagrup.com/GestionDocumenta...
# 634   http://intranet.juliagrup.com/GestionDocumenta...
# 686   http://intranet.juliagrup.com/GestionDocumenta...
# 688   http://intranet.juliagrup.com/GestionDocumenta...
# 697   http://intranet.juliagrup.com/GestionDocumenta...
# 699   http://intranet.juliagrup.com/GestionDocumenta...
# 700   http://intranet.juliagrup.com/GestionDocumenta...
# 727   http://intranet.juliagrup.com/GestionDocumenta...
# 769   http://intranet.juliagrup.com/GestionDocumenta...
# 771   http://intranet.juliagrup.com/GestionDocumenta...
# 772   http://intranet.juliagrup.com/GestionDocumenta...
# 779   http://intranet.juliagrup.com/GestionDocumenta...
# 789   http://intranet.juliagrup.com/GestionDocumenta...
# 793   http://intranet.juliagrup.com/GestionDocumenta...
# 795   http://intranet.juliagrup.com/GestionDocumenta...
# 800   http://intranet.juliagrup.com/GestionDocumenta...
# 815   http://intranet.juliagrup.com/GestionDocumenta...
# 818   http://intranet.juliagrup.com/GestionDocumenta...
# 819   http://intranet.juliagrup.com/GestionDocumenta...
# 826   http://intranet.juliagrup.com/GestionDocumenta...
# 831   http://intranet.juliagrup.com/GestionDocumenta...
# 834   http://intranet.juliagrup.com/GestionDocumenta...
# 876   http://intranet.juliagrup.com/GestionDocumenta...
# 877   http://intranet.juliagrup.com/GestionDocumenta...
# 913   http://intranet.juliagrup.com/GestionDocumenta...
# 914   http://intranet.juliagrup.com/GestionDocumenta...
# 918   http://intranet.juliagrup.com/GestionDocumenta...
# 921   http://intranet.juliagrup.com/GestionDocumenta...
# 922   http://intranet.juliagrup.com/GestionDocumenta...
# 955   http://intranet.juliagrup.com/GestionDocumenta...
# 964   http://intranet.juliagrup.com/GestionDocumenta...
# 968   http://intranet.juliagrup.com/GestionDocumenta...
# 984   http://intranet.juliagrup.com/GestionDocumenta...
# 987   http://intranet.juliagrup.com/GestionDocumenta...
# 988   http://intranet.juliagrup.com/GestionDocumenta...
# 994   http://intranet.juliagrup.com/GestionDocumenta...
# 1001  http://intranet.juliagrup.com/GestionDocumenta...
# 2134  http://intranet.juliagrup.com/GestionDocumenta...
# 2196  http://intranet.juliagrup.com/GestionDocumenta...
# 2197  http://intranet.juliagrup.com/GestionDocumenta...
# 2198  http://intranet.juliagrup.com/GestionDocumenta...
# 2203  http://intranet.juliagrup.com/GestionDocumenta...
# 2204  http://intranet.juliagrup.com/GestionDocumenta...
# 2215  http://intranet.juliagrup.com/GestionDocumenta...
# 2232  http://intranet.juliagrup.com/GestionDocumenta...
# 2243  http://intranet.juliagrup.com/GestionDocumenta...
# 2269  http://intranet.juliagrup.com/GestionDocumenta...
# 2283  http://intranet.juliagrup.com/GestionDocumenta...
# 2284  http://intranet.juliagrup.com/GestionDocumenta...
# 2286  http://intranet.juliagrup.com/GestionDocumenta...
# 2298  http://intranet.juliagrup.com/GestionDocumenta...
# 2299  http://intranet.juliagrup.com/GestionDocumenta...
# 2301  http://intranet.juliagrup.com/GestionDocumenta...
# 2307  http://intranet.juliagrup.com/GestionDocumenta...
# 2329  http://intranet.juliagrup.com/GestionDocumenta...
# 2330  http://intranet.juliagrup.com/GestionDocumenta...
# 2332  http://intranet.juliagrup.com/GestionDocumenta...
# 2333  http://intranet.juliagrup.com/GestionDocumenta...
# 2334  http://intranet.juliagrup.com/GestionDocumenta...
# 2335  http://intranet.juliagrup.com/GestionDocumenta...
# 2344  http://intranet.juliagrup.com/GestionDocumenta...
# 2346  http://intranet.juliagrup.com/GestionDocumenta...
# 2354  http://intranet.juliagrup.com/GestionDocumenta...
# 2357  http://intranet.juliagrup.com/GestionDocumenta...
# 2381  http://intranet.juliagrup.com/GestionDocumenta...
# 2382  http://intranet.juliagrup.com/GestionDocumenta...
# 2383  http://intranet.juliagrup.com/GestionDocumenta...
# 2384  http://intranet.juliagrup.com/GestionDocumenta...
# 2402  http://intranet.juliagrup.com/GestionDocumenta...
# 2403  http://intranet.juliagrup.com/GestionDocumenta...
# 2404  http://intranet.juliagrup.com/GestionDocumenta...
# 2412  http://intranet.juliagrup.com/GestionDocumenta...
# 2436  http://intranet.juliagrup.com/GestionDocumenta...
# 2439  http://intranet.juliagrup.com/GestionDocumenta...
# 2440  http://intranet.juliagrup.com/GestionDocumenta...
# 2441  http://intranet.juliagrup.com/GestionDocumenta...
# 2489  http://intranet.juliagrup.com/GestionDocumenta...
# 2495  http://intranet.juliagrup.com/GestionDocumenta...

# %%
df_output.to_json("kavehome_clean.json", orient='records')

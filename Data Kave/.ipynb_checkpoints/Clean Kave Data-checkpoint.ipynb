# %%
import pandas as pd
import numpy as np
import unidecode
pd.set_option('display.max_rows', 400)
pd.set_option('display.max_columns', None)
import re

# %%
def drop_columns(df, columns):
    df.drop(columns,axis=1, inplace=True)
    return df

# %%
def get_furniture(row, furnitures):
    for f in furnitures:
        if f in row[1]:
            return f
    return 'otro'

# %%
df = pd.read_csv("descripcion_productos.csv", encoding='utf-8', sep=";")

# %%
# variables
columns = list(df.columns)
l = ['sku','descripcion','img_ambiente', 'img','Material de las patas',
     'Materiales','Construcción de la estructura','Forma del producto',
     'Material principal','Color principal','Año de publicación','Colores',
     'Estilo principal','Estancias']

# the order of the categories matter!!
furnitures = ['abridor', 'alfombra', 'almohada', 'ambientador', 'aparado',
       'aplique', 'armario', 'asiento', 'azucarero', 'bandeja', 'ban',
       'base', 'biombo', 'bolsa', 'bol', 'bombilla', 'book',
       'bote', 'botell', 'butaca', 'cabecero', 'caja',
       'cajon', 'cama', 'cambiador', 'canape', 'candelabro', 'cest', 'chaise',
       'cojin', 'colchoneta', 'colchon', 'colgador', 'consola', 'copa', 
       'corona', 'cortina', 'cuadro', 'cubo', 'delantal', 'escalera', 
       'escobilla', 'escritorio', 'espejo', 'estanteria', 'estante', 'estrella', 
       'figura', 'ganchos', 'guirnalda', 'hamaca', 'jabon', 'jarra', 'jarron', 
       'lampara', 'libreria', 'lienzo', 'llitera', 'macet', 
       'mantel', 'marco', 'mecedora', 'mesa', 'mesita', 'modulo', 'mortero',
       'mueble', 'neceser', 'panel', 'pantalla', 'silla', 'papel', 'perchero', 'pizarra', 
       'planta', 'plato', 'portacepillo', 'protector', 'puf', 'reloj',
       'reposacabezas', 'reposapies', 'revistero', 'rodillo', 'sabana',
       'salero', 'set',  'sillon', 'sofacama', 'sofa',
       'somier', 'tabla', 'taburete', 'tapiceria', 'tapiz', 'taza',
       'tetera', 'tipi', 'toall', 'tumbona', 'vaso', 'vela', 'ventosas',
       'zapatero']

file = open("links.txt", "r", encoding='utf-8')
url = file.read().split('\n')
file.close()
    
for i,f in enumerate(url):
    url[i] = unidecode.unidecode(f.lower())
url.remove('chaiselongue')
url.remove('cesto')
url.remove('puff')

url = url + ['chaise', 'cest', 'puf']

# ban -> banco, banqueta
# macet -> macetas, macetero
# cest -> cesta, cestas, cestos
# toall -> toalla, toallas, toallero
# jarr -> jarra, jarron

# %%
# get columns of interest
for x in l:
    columns.remove(x)
df = drop_columns(df, columns)

# drop rows with a lot of NA
df.dropna(how='all', subset=['Material de las patas','Materiales','Construcción de la estructura',
                             'Forma del producto','Material principal','Color principal',
                             'Colores','Estilo principal','Estancias'], inplace=True)
df.dropna(subset=['descripcion'], inplace=True)

# lowercase
df['descripcion'] = df['descripcion'].str.lower()
df['descripcion'] = df.apply(lambda x: unidecode.unidecode(x[1]), axis=1)

# add label
df['id'] = df.apply(lambda x: get_furniture(x, furnitures), axis=1)

# Año de publicacion
df['Año de publicación'] = df['Año de publicación'].str.rstrip()

# %%
df_output = df[df['id'].isin(url)]

# %%
df = pd.read_csv("descripcion_productos.csv", encoding='utf-8', sep=";")
df = drop_columns(df, columns)

df.dropna(subset=['descripcion'], inplace=True)

# lowercase
df['descripcion'] = df['descripcion'].str.lower()
df['descripcion'] = df.apply(lambda x: unidecode.unidecode(x[1]), axis=1)

# add label
df['id'] = df.apply(lambda x: get_furniture(x, furnitures), axis=1)


# Año de publicacion
df['Año de publicación'] = df['Año de publicación'].str.rstrip()

df_output2 = df_output.append(df[df['sku'].isin(dif)], ignore_index=True).reset_index(drop=True)
# Out:
# C:\Users\Luis\AppData\Local\Temp/ipykernel_14224/2501052019.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_output2 = df_output.append(df[df['sku'].isin(dif)], ignore_index=True).reset_index(drop=True)

# %%
df_output2
# Out:
#              sku                                        descripcion  \
# 0     2027135190                           somier talo 135 x 190 cm
# 1     2027150190                           somier talo 150 x 190 cm
# 2      770106BLA               ode zapatero 3 puertas metal blanco
# 3      770306BLA               ode zapatero 5 puertas metal blanco
# 4     807809ADUK  asai lampara sobremesa cromada brillo adaptado...
# ...          ...                                                ...
# 2990  YG0255CP46  silla better de madera maciza de acacia acabad...
# 2991   AA4103R05        aplique ginebra de acero con acabado blanco
# 2992     C052U05              crema taburete blanco altura 60-81 cm
# 2993   YG0253J01  silla better de madera maciza de acacia y cuer...
# 2994   YG0253J12  silla better de madera maciza de acacia y cuer...
#
#                                            img_ambiente  \
# 0                                                   NaN
# 1                                                   NaN
# 2     https://storage.googleapis.com/web-pro-nilo-ka...
# 3     https://storage.googleapis.com/web-pro-nilo-ka...
# 4                                                   NaN
# ...                                                 ...
# 2990                                                NaN
# 2991  https://storage.googleapis.com/web-pro-nilo-ka...
# 2992                                                NaN
# 2993                                                NaN
# 2994                                                NaN
#
#                                                     img Material de las patas  \
# 0     http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 1     http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 2     http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 3     http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 4     http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# ...                                                 ...                   ...
# 2990  http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 2991  http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 2992  http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 2993  http://intranet.juliagrup.com/GestionDocumenta...                   NaN
# 2994  http://intranet.juliagrup.com/GestionDocumenta...                   NaN
#
#            Materiales Construcción de la estructura Forma del producto  \
# 0                 NaN                           NaN        Rectangular
# 1                 NaN                           NaN        Rectangular
# 2               Acero                           NaN        Rectangular
# 3               Acero                           NaN        Rectangular
# 4     Acero, Plástico                           NaN             Cónico
# ...               ...                           ...                ...
# 2990              NaN                           NaN                NaN
# 2991            Acero                           NaN         Triangular
# 2992              NaN                           NaN                NaN
# 2993              NaN                           NaN                NaN
# 2994              NaN                           NaN                NaN
#
#      Material principal Color principal Año de publicación   Colores  \
# 0                 Metal            Gris           01/08/18      Gris
# 1                 Metal            Gris           01/08/18      Gris
# 2                 Metal          Blanco           01/01/13    Blanco
# 3                 Metal          Blanco           01/01/13    Blanco
# 4                 Metal        Plateado           26/08/17  Plateado
# ...                 ...             ...                ...       ...
# 2990                NaN             NaN                NaN       NaN
# 2991              Metal          Blanco           30/04/19    Blanco
# 2992                NaN             NaN           01/01/13       NaN
# 2993                NaN             NaN                NaN       NaN
# 2994                NaN             NaN                NaN       NaN
#
#      Estilo principal                                         Estancias  \
# 0             Moderno                                        Dormitorio
# 1             Moderno                                        Dormitorio
# 2             Moderno                      Salón, Dormitorio, Recibidor
# 3             Moderno                      Salón, Dormitorio, Recibidor
# 4             Moderno  Salón, Dormitorio, Recibidor, Espacio de trabajo
# ...               ...                                               ...
# 2990              NaN                                               NaN
# 2991          Nórdico  Recibidor, Dormitorio, Salón, Espacio de trabajo
# 2992              NaN                                               NaN
# 2993              NaN                                               NaN
# 2994              NaN                                               NaN
#
#             id
# 0       somier
# 1       somier
# 2     zapatero
# 3     zapatero
# 4      lampara
# ...        ...
# 2990     silla
# 2991   aplique
# 2992  taburete
# 2993     silla
# 2994     silla
#
# [2995 rows x 15 columns]

# %%
validation = pd.read_excel(r'../Validation/Validation Dataset.xlsx')

# %%
skus = set(list(validation['PRODUCTO1'].unique())+list(validation['PRODUCTO2'].unique())+list(validation['PRODUCTO3'].unique()))

skus2 = set(df_output['sku'].unique())
dif = list(skus - skus2)

# %%
sorted(dif)
# Out:
# ['AA0013R01',
#  'AA0331R54',
#  'AA2952R35',
#  'AA4103R05',
#  'AA6238J12',
#  'AA6238J60',
#  'AA6456R53',
#  'AA6525M01',
#  'AA6616R34',
#  'AA7153J03',
#  'AA8045J33',
#  'AA8355J39',
#  'AA8704J09',
#  'AA8808C07',
#  'AB0052',
#  'AB0237R05',
#  'C052U05',
#  'C080C07',
#  'C639J14',
#  'C934M46',
#  'C994M33',
#  'CC2097J10',
#  'CC6052M46',
#  'CC6119M47',
#  'S598J03',
#  'S626J03',
#  'S641R15',
#  'S727MN14',
#  'S748MN14',
#  'S794R02',
#  'S794R10',
#  'S801_40D_G339',
#  'Y007L05',
#  'Y008L05',
#  'YG0253J01',
#  'YG0253J12',
#  'YG0255CP46']

# %%
my_list = sorted(list(validation['PRODUCTO1'].unique())+list(validation['PRODUCTO2'].unique())+list(validation['PRODUCTO3'].unique()))

freq = {}
for item in my_list:
    if item in freq:
        freq[item] += 1
    else:
        freq[item] = 1
freq
# Out:
# {'A102FN39': 1,
#  'A177F10': 1,
#  'A435C07': 1,
#  'A435C25': 1,
#  'A436C10': 1,
#  'A436C25': 1,
#  'A482J05': 1,
#  'AA0013R01': 1,
#  'AA0025C29': 1,
#  'AA0131R01': 1,
#  'AA0137R83': 1,
#  'AA0331R54': 1,
#  'AA0600C07': 1,
#  'AA0600C10': 1,
#  'AA0600C25': 1,
#  'AA0733M46': 1,
#  'AA0734M46': 1,
#  'AA1087J14': 1,
#  'AA1101FN35': 1,
#  'AA1256FN35': 1,
#  'AA1278M05': 1,
#  'AA1568J06': 1,
#  'AA1758RF35': 2,
#  'AA2014R01': 2,
#  'AA2519M46': 2,
#  'AA2525M41': 1,
#  'AA2547R83': 2,
#  'AA2952R35': 1,
#  'AA2973C15': 1,
#  'AA3821R23': 1,
#  'AA3822R83': 1,
#  'AA3888R01': 1,
#  'AA4103R05': 1,
#  'AA4242M46': 1,
#  'AA4288R25': 1,
#  'AA4299R35': 1,
#  'AA4371K05': 1,
#  'AA4380K26': 1,
#  'AA4393K12': 1,
#  'AA4614M87': 1,
#  'AA4686C15': 1,
#  'AA5030M46': 1,
#  'AA5086FN46': 1,
#  'AA5097J03': 3,
#  'AA5118J03': 1,
#  'AA5128J35': 1,
#  'AA5129J35': 1,
#  'AA5254M46': 1,
#  'AA5720FN46': 1,
#  'AA5724FN46': 2,
#  'AA5836R53': 1,
#  'AA5852R53': 1,
#  'AA6123M87': 2,
#  'AA6206M12': 1,
#  'AA6238J12': 1,
#  'AA6238J60': 1,
#  'AA6239J12': 1,
#  'AA6270J86': 1,
#  'AA6286SN24': 1,
#  'AA6286SN39': 1,
#  'AA6288SN24': 1,
#  'AA6396J35': 1,
#  'AA6398J35': 1,
#  'AA6404J35': 1,
#  'AA6431J14': 1,
#  'AA6456R53': 1,
#  'AA6461R01': 1,
#  'AA6480R01': 1,
#  'AA6525M01': 1,
#  'AA6616R34': 1,
#  'AA6907C03': 1,
#  'AA6983J24': 1,
#  'AA6985J12': 1,
#  'AA6988J81': 1,
#  'AA7001J12': 1,
#  'AA7048J33': 1,
#  'AA7049J60': 2,
#  'AA7050J12': 1,
#  'AA7051J35': 1,
#  'AA7107J24': 1,
#  'AA7131J12': 1,
#  'AA7135J09': 1,
#  'AA7142J82': 1,
#  'AA7149J10': 1,
#  'AA7151J01': 3,
#  'AA7151J12': 1,
#  'AA7153J03': 1,
#  'AA7362J12': 2,
#  'AA7441J12': 1,
#  'AA7447J19': 1,
#  'AA7726J35': 1,
#  'AA7776J33': 2,
#  'AA7809C37': 1,
#  'AA7892R83': 1,
#  'AA7896R01': 1,
#  'AA7922M27': 1,
#  'AA7925M42': 1,
#  'AA7925M46': 1,
#  'AA7926M41': 1,
#  'AA7926M46': 2,
#  'AA7928M41': 1,
#  'AA7928M46': 2,
#  'AA7929M42': 2,
#  'AA7929M46': 2,
#  'AA7930M41': 1,
#  'AA7930M46': 2,
#  'AA7988M46': 1,
#  'AA7989M46': 1,
#  'AA8045J33': 1,
#  'AA8171K03': 1,
#  'AA8172K03': 2,
#  'AA8177K03': 1,
#  'AA8178K03': 3,
#  'AA8186K03': 3,
#  'AA8224J29': 2,
#  'AA8226J03': 1,
#  'AA8232J11': 2,
#  'AA8235J12': 1,
#  'AA8264J12': 1,
#  'AA8268J39': 1,
#  'AA8286J05': 1,
#  'AA8299J33': 2,
#  'AA8331J31': 1,
#  'AA8333J31': 1,
#  'AA8335J31': 1,
#  'AA8341J14': 2,
#  'AA8355J39': 1,
#  'AA8359J30': 1,
#  'AA8514C07': 1,
#  'AA8527C03': 2,
#  'AA8622M43': 2,
#  'AA8655AP01': 1,
#  'AA8655AP33': 1,
#  'AA8660': 1,
#  'AA8664': 1,
#  'AA8665': 1,
#  'AA8700J12': 2,
#  'AA8704J09': 1,
#  'AA8745FN46': 3,
#  'AA8745J01': 1,
#  'AA8748FN46': 2,
#  'AA8778J33': 1,
#  'AA8781FN46': 1,
#  'AA8785FN46': 1,
#  'AA8791J39': 1,
#  'AA8797FN46': 1,
#  'AA8798J33': 1,
#  'AA8799C07': 1,
#  'AA8808C07': 1,
#  'AA8967J33': 1,
#  'AA8996J03': 1,
#  'AA9007J12': 2,
#  'AA9084J86': 1,
#  'AA9991J01': 1,
#  'AB0007J05': 1,
#  'AB0052': 1,
#  'AB0137M46': 1,
#  'AB0139M46': 1,
#  'AB0154FN46': 2,
#  'AB0159FN46': 1,
#  'AB0160FN46': 1,
#  'AB0164FN46': 2,
#  'AB0237R05': 1,
#  'AB0388R53': 1,
#  'AB0528FN46': 1,
#  'C052U05': 1,
#  'C061U01': 1,
#  'C080C07': 1,
#  'C366M33': 1,
#  'C416M46': 1,
#  'C417M01': 1,
#  'C423M01': 1,
#  'C436K09': 1,
#  'C473L05': 1,
#  'C489L05': 1,
#  'C613M46': 1,
#  'C639J14': 1,
#  'C747K09': 1,
#  'C747M33': 1,
#  'C747M40': 2,
#  'C747M90': 2,
#  'C796M33': 1,
#  'C804R02': 3,
#  'C838R33': 1,
#  'C934M46': 1,
#  'C994M33': 1,
#  'CC0006M40': 1,
#  'CC0014M40': 1,
#  'CC0063J05': 2,
#  'CC0092L05': 1,
#  'CC0095L05': 1,
#  'CC0180C05': 1,
#  'CC0252VD03': 1,
#  'CC0253BG19': 1,
#  'CC0254UE02': 1,
#  'CC0276J15': 1,
#  'CC0297J25': 1,
#  'CC0309UE09': 1,
#  'CC0312UE86': 1,
#  'CC0379CWQ11': 1,
#  'CC0436J33': 1,
#  'CC0531L05': 1,
#  'CC0555S12': 2,
#  'CC0555S15': 1,
#  'CC0579R02': 3,
#  'CC0637UE02': 1,
#  'CC0717S12': 1,
#  'CC0741L05': 1,
#  'CC0749UE11': 1,
#  'CC0825U10': 1,
#  'CC0826PN36': 1,
#  'CC0836R02': 3,
#  'CC0837R02': 1,
#  'CC0838R02': 1,
#  'CC0839S01': 1,
#  'CC0855J25': 1,
#  'CC0912U10H': 1,
#  'CC0934PK26': 1,
#  'CC0954M43': 3,
#  'CC0986PK03': 1,
#  'CC1011J15': 1,
#  'CC1016J25': 1,
#  'CC1025J12': 2,
#  'CC1047M90': 1,
#  'CC1073M46': 1,
#  'CC1081J03': 1,
#  'CC1081U10H': 1,
#  'CC1104PR05': 1,
#  'CC1155JU25': 1,
#  'CC1221S02': 2,
#  'CC1221S02H': 1,
#  'CC1221S05': 1,
#  'CC1230S05': 1,
#  'CC1344AB12': 1,
#  'CC1344AB15': 1,
#  'CC1724M46': 1,
#  'CC1726M46': 1,
#  'CC1738J12': 1,
#  'CC1807PK81': 1,
#  'CC1841PR05': 1,
#  'CC1882AB03': 1,
#  'CC1883AB15': 1,
#  'CC1884AB14': 1,
#  'CC1948P10': 1,
#  'CC1960M33': 1,
#  'CC1964M03': 1,
#  'CC1974M40': 2,
#  'CC1974M41': 1,
#  'CC1979M33': 2,
#  'CC1980M42': 1,
#  'CC2097J10': 1,
#  'CC2100J12': 1,
#  'CC2108MV12': 1,
#  'CC2109MV12': 1,
#  'CC2111MV12': 1,
#  'CC2112MV12': 1,
#  'CC2160M46': 1,
#  'CC2172M46': 1,
#  'CC2174M46': 1,
#  'CC2186VD14': 1,
#  'CC2228J11': 2,
#  'CC2258PR05': 2,
#  'CC2261GR39': 1,
#  'CC3001J33': 1,
#  'CC3015U01': 1,
#  'CC5078J12': 1,
#  'CC5079J03': 2,
#  'CC5079J12': 1,
#  'CC5080J12': 2,
#  'CC5106J46': 1,
#  'CC5115J01': 1,
#  'CC5116J01': 1,
#  'CC5117J01': 1,
#  'CC5162M43': 1,
#  'CC5171VD14': 1,
#  'CC5180C01': 1,
#  'CC5188J01': 1,
#  'CC5189J03': 1,
#  'CC5201M01': 1,
#  'CC5201M46': 1,
#  'CC5209VD03': 1,
#  'CC5212J01': 1,
#  'CC5225J01': 1,
#  'CC6005M43': 1,
#  'CC6020M05': 1,
#  'CC6029KY15': 1,
#  'CC6052M46': 1,
#  'CC6054J11': 1,
#  'CC6068J12': 1,
#  'CC6070J12': 1,
#  'CC6119M47': 1,
#  'DI011M46': 1,
#  'EA326FN39': 1,
#  'EA331FN39': 1,
#  'IT0070PR60': 2,
#  'IT0071PR60': 1,
#  'IT0072PR60': 1,
#  'IT0227J05': 1,
#  'IT0303J33': 1,
#  'IT0336J35': 1,
#  'IT0343J35': 1,
#  'IT0474M83': 1,
#  'IT0475M83': 2,
#  'LH0162R03': 2,
#  'LH0234J18': 1,
#  'LH0235J01': 1,
#  'LH0235J05': 1,
#  'LH0238J60': 1,
#  'LH0239J60': 1,
#  'LH0310J14': 1,
#  'LH0312J01': 1,
#  'LH0314J12': 1,
#  'LH0450J33': 1,
#  'LH0611FN46': 1,
#  'LH0614FN46': 1,
#  'LH0622J35': 1,
#  'LH0634J12': 1,
#  'LH0651J33': 1,
#  'MH009M09_': 1,
#  'S472CH12': 1,
#  'S472CH14': 2,
#  'S473CH02': 1,
#  'S481LD81': 1,
#  'S489PK03': 1,
#  'S490PT02': 1,
#  'S490PT09': 1,
#  'S490PT86': 1,
#  'S492CH14': 2,
#  'S521J03': 1,
#  'S547JU80': 1,
#  'S547JU85': 1,
#  'S547PK03': 1,
#  'S548JU85': 1,
#  'S548PK03': 1,
#  'S571GR39': 1,
#  'S573LN19': 1,
#  'S574GR39': 3,
#  'S574SN39': 1,
#  'S574SN81': 1,
#  'S575GR39': 1,
#  'S575LN15': 3,
#  'S575SN81': 1,
#  'S581PK03': 1,
#  'S587BB14': 1,
#  'S598J03': 1,
#  'S626J03': 1,
#  'S639M46': 1,
#  'S641R15': 1,
#  'S663JU03': 1,
#  'S663JU80': 1,
#  'S663PK03': 1,
#  'S664JU03': 1,
#  'S664JU80': 1,
#  'S664JU85': 1,
#  'S664PK03': 1,
#  'S685LN15': 1,
#  'S718GC12': 1,
#  'S727MN14': 1,
#  'S748MN14': 1,
#  'S754MN14': 1,
#  'S756MN14': 2,
#  'S757MN14': 1,
#  'S793_21_LO12': 1,
#  'S793_40_MN14': 1,
#  'S793_41_LO12': 1,
#  'S793_41_MN14': 2,
#  'S794R02': 1,
#  'S794R10': 1,
#  'S799_60_SN39': 1,
#  'S800_30_SO33': 2,
#  'S800_40_SO33': 2,
#  'S800_41_SO33': 1,
#  'S801_40D_G339': 1,
#  'S801_40I_GR39': 1,
#  'S801_53_GR39': 1,
#  'S805_30_PS33': 1,
#  'S805_40D_PS33': 2,
#  'S805_40I_PS33': 1,
#  'SN006M47': 1,
#  'Y007L05': 2,
#  'Y008L05': 2,
#  'YG0163R01': 3,
#  'YG0253J01': 1,
#  'YG0253J12': 1,
#  'YG0255CP46': 1}

# %%
for i,x in enumerate(dif):
    if x not in sorted(list(df[df['sku'].isin(dif)]['sku'])):
        print(freq[x], x)
# Out:
# 1 AA8045J33
# 1 AA6238J60
# 1 S641R15
# 1 AB0052
# 1 AA8704J09
# 1 S626J03
# 1 AA8808C07
# 1 AA6238J12
# 1 AB0237R05
# 1 S727MN14
# 1 AA8355J39
# 1 AA7153J03
# 1 S748MN14
# 1 C934M46
# 1 S598J03
# 1 AA2952R35
# 1 S801_40D_G339

# %%
3/60 *100
# Out:
# 5.0

# %%
df_output.to_json("kavehome_clean.json", orient='records')

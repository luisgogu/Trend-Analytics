# %%
import pandas as pd
import numpy as np
import unidecode
pd.set_option('display.max_rows', 400)
pd.set_option('display.max_columns', None)
import re

# %%
def drop_columns(df, columns):
    df.drop(columns,axis=1, inplace=True)
    return df

# %%
def get_furniture(row, furnitures):
#     file = open("links.txt", "r", encoding='utf-8')
#     furnitures = file.read().split('\n')
#     file.close()
    
#     for i,f in enumerate(furnitures):
#         furnitures[i] = unidecode.unidecode(f.lower())
    
    for f in furnitures:
        if f in row[1]:
            return f
    return 'otro'

# %%
df = pd.read_csv("descripcion_productos.csv", encoding='utf-8', sep=";")

# %%
# variables
columns = list(df.columns)
l = ['sku','descripcion','img_ambiente', 'img','Material de las patas',
     'Materiales','Construcción de la estructura','Forma del producto',
     'Material principal','Color principal','Año de publicación','Colores',
     'Estilo principal','Estancias']

furnitures = ['somier', 'zapatero', 'lampara', 'mes', 'mueble', 'estante',
              'otro', 'espejo', 'cuadro', 'cojin', 'alfombra', 'jarron',
              'reposapies', 'cajon', 'reloj', 'perchero', 'caja', 'bandeja',
              'cest', 'marco', 'colgador', 'jarra', 'papel', 'almohada', 'cama',
              'cambiador', 'bols', 'butaca', 'protector', 'silla', 'taburete',
              'escritorio', 'sillon', 'sofa', 'armario', 'asiento', 'colchon',
              'canape', 'cortina', 'escalera', 'taza', 'plato', 'bol', 'planta', 
              'tabla', 'mortero', 'vela', 'delantal','macet', 'vaso', 'copa', 
              'ambientador','sabana','panel', 'mant', 'aplique', 'lienzo', 'puf',
              'toall', 'bombilla', 'jabon', 'cepill', 'figura', 'sal', 'bote', 
              'botell', 'set', 'escob', 'tetera', 'neceser', 'rodillo', 'azucar', 
              'tumbona', 'cabecer', 'base', 'aparado', 'candelabro', 'estrell', 'book', 'libr']

# %%
# get columns of interest
for x in l:
    columns.remove(x)
df = drop_columns(df, columns)

# drop rows with a lot of NA
df.dropna(how='all', subset=['Material de las patas','Materiales','Construcción de la estructura',
                             'Forma del producto','Material principal','Color principal',
                             'Colores','Estilo principal','Estancias'], inplace=True)
df.dropna(subset=['descripcion'], inplace=True)

# lowercase
df['descripcion'] = df['descripcion'].str.lower()
df['descripcion'] = df.apply(lambda x: unidecode.unidecode(x[1]), axis=1)

# add label
df['Mueble'] = df.apply(lambda x: get_furniture(x, furnitures), axis=1)

# %%
for x in df[df['Mueble'] == 'otro']['descripcion']:
    print(x)
# Out:
# exist tapiz mural algodon lana multicolor
# next terrario cristal metal negro
# shibori revistero metal blanco poly rattan natural
# marta paraguero cemento gris
# aine cuenco ceramica violeta
# sybilla terrario cristal metal negro
# biombo dai de acero con acabado dorado 123 x 182 cm
# avaline biombo de madera maciza de teca 135 x 180 cm
# pack colgante decorativo triangulos yaiti
# guirnalda astrea fases luna fondo azul
# cuenco bintou de metal granate
# aceitera-vinagrera rohan de vidrio marron 100% reciclado
# aceitera-vinagrera rohan de vidrio azul 100% reciclado
# pinza de servir yanila de madera maciza de acacia
# porta utensilios de cocina yanila de madera maciza acacia
# limpiador de madera sterina 500 ml
# biombo lalita de ratan 150 x 180 cm
# guirnalda stelly dorado 1,9 m
# vitrina trixie acero con acabado negro 70 x 143 cm
# tapiz mural nana 30 x 40 cm
# tapiz mural nana de algododon beige 25 x 50
# guirnalda luminosa led yulia beige 10 cm
# guirnalda luminosa led yulia verde 10 cm
# burra tipi maralis de madera maciza de fresno 148 x 50 cm
# burro de pared para ropa galatia de melamina y acero con acabado negro 60 x 162 cm
# burro para ropa con banqueta galatia de melamina y acero con acabado negro 100 x 150 cm
# guirnalda con banderines zalia 100% algodon organico (gots) gris
# guirnalda con banderines zalia 100% algodon organico (gots) amarillo
# tipi darlyn 100% algodon azul y patas de madera maciza de pino
# revistero de pared yamine metal negro 33 x 45 cm
# corona luminosa mishell dorada 35 cm
# kuveni pure terrazzo washbasin white color
# manual de cocteleria
# craft brew
# pulpo
# calma
# dormir
# felicidad
# placeres veganos
# catalunya
# la carta de vinos, por favor
# magia para el dia a dia
# n brida u-60 oxidon
# loya banqueta gris de madera maciza de haya 128 cm
# loya banqueta beige de madera maciza de haya 128 cm
# dyla funda banqueta grafito
# vania mecedora gris
# dyla banqueta terciopelo azul y madera maciza de haya 111 cm
# dyla banqueta terciopelo turquesa y madera maciza de haya 11
# consola rewena sobre porcelanico acabado kalos blanco 110 x 75 cm
# consola rewena sobre porcelanico 110 x 75 cm
# consola shantay acero con acabado negro 100 x 80 cm
# consola elisenda 110 x 76 cm dorada y con marmol
# consola duilia 110 x 85 cm con cristal tintado
# banco yukari 136 cm fsc 100%
# mecedora otilia
# banco calixta de madera maciza de teca 120 cm
# banco safara madera maciza de teca reciclada 100 cm
# banco safara madera maciza de teca reciclada 150 cm
# alaia banco 160 x 45 cm  madera maciza de acacia y acero aca
# consola 115x75 acacia natural
# moises leonela de madera maciza fresno y contrachapado 97 x 62 cm fsc 100%
# thinh vitrina 95x187 metal, acacia natural
# banco infantil marzieh de ratan 67 cm
# consola burano de cristal 125 x 78 cm
# topper freya 90 x 190 cm
# topper freya 135 x 190 cm
# topper freya 150 x 190 cm
# exprimidor odena de vidrio transparente
# lapicero jeannie de metal rosa
# tapiz mural delmare 100% algodon velero multicolor 25 x 25 cm
# guirnalda con banderines celia 100% algodon organico (gots) multicolor
# guirnalda con banderines nami 100% algodon organico (gots) pastel
# banco beyla con 2 puertas de madera maciza y chapa de roble 98,5 cm fsc 100%
# baliza solar berarda de aluminio con acabado negro 50 cm
# guirnalda luminosa led amabile blanco 17,5 cm
# kesia consola 120x85 chapa nogal, dm grafito mate
# glb trk ceil clamp wht
# consola palmia 140 x 81 cm de madera maciza de mango
# modulo compo 3 plazas gris claro 232 cm
# brazo compo gris oscuro
# brazo compo azul
# nordico gianela 60 x 120 cm
# legara legara modulo 1pl gris
# legara legara modulo br derecha gris
# stellar comoda 100 x 90 cm con chapa de roble
# carrito carmelita de madera maciza de pino natural y mdf blanco fsc mix credit
# revistero siana negro y metal negro
# revistero siana beige y metal dorado
# mecedora metal blanco borrego blanco
# rap revistero metal negro
# helene decoracion mural metal dorado
# berthile colgante decorativo 13 cm metal blanco
# mix suculentas artificial con estructura de metal colgante negro
# mix suculenta artificial con estructura de metal negro 13 cm
# revistero aviva
# espatula de cocina yanila de madera maciza de acacia
# limpiador de tejidos sterina 500 ml
# biombo krysia de ratan 180 x 180 cm
# biombo margaret de ratan natural  y verde 165 x 180 cm
# revistero aubrey negro
# revistero aubrey plateado
# guirnalda stelly metal negro 1,9 m
# guirnalda maille gris 1,9 m
# guirnalda maille metal negro 1,9 m
# corona luminosa nelsa de metal plateado
# corona de navidad nelsa
# guirnalda luminosa led yulia rosa 10 cm
# gimnasio infantil tipi maralis madera maciza de haya
# guirnalda decorativa zidanelia de madera y dorado
# corona de navidad willemina multicolor
# guirnalda con banderines zalia 100% algodon organico (gots) rosa
# tipi miris 100% algodon multicolor y patas de madera maciza de pino
# tipi darlyn 100% algodon rosa y patas de madera maciza de pino
# tipi darlyn 100% algodon blanco y patas de madera maciza de pino
# tapiz mural thaide 100% algodon arcoiris multicolor 60 x 52 cm
# tapiz mural liane 25 x 35 cm
# biombo ondine metal negro 124,5 x 184 cm
# abridor bluma de marmol blanco
# abridor bluma de marmol verde
# banqueta cesia piel de bufalo marron con pie de madera 120 cm
# revistero elenys de metal con acabado negro y yute con acabado natural
# guirnalda luminosa narel gris 1,9 m
# guirnalda luminosa narel dorado 1,9 m
# corona luminosa mishell gris 35 cm
# kuveni pure terrazzo washbasin dark color
# fuente de horno sheilyn beige 31 x 16 cm
# ramen
# superzumos
# confianza
# gin: mezclar, agitar, remover
# ron: mezclar, agitar, remover
# tenzo mecedora blanco
# tenzo mecedora natural
# alaia banco 180 madera negro
# alaia banco 180 x 45 cm  madera maciza de acacia y acero aca
# loya banqueta grafito de madera maciza de haya 128 cm
# dyla banqueta grafito de madera maciza de haya 111 cm
# dyla banqueta beige de madera maciza de haya 111 cm
# dyla funda banqueta beige
# meryl mecedora gris
# solara banco blanco de madera maciza de caucho 120 cm
# solara banco natural de madera maciza de caucho 120 cm
# carabel banco de acero y chapado de nogal 100 cm
# dyla banqueta terciopelo gris y madera maciza de haya 111 cm
# vitrina alen de madera maciza de acacia 110 x 166 cm
# torre de aprendizaje nuun de chapa de abedul
# banco beida madera maciza teca 120 cm
# hamaca plegable de exterior adredna beige de madera maciza acacia fsc 100%
# hamaca plegable de exterior adredna verde de madera maciza acacia fsc 100%
# hamaca plegable de exterior adredna terracota de madera maciza acacia fsc 100%
# trona evolutiva nuun chapa abedul
# alaia banco de madera de acacia negro y patas de acero negro
# tocador galatia de cristal y melamina negro y patas de acero acabado negro 80 x 44,5 cm
# cuna nunila de mdf blanco 60 x 120 cm fsc 100%
# cuna evolutiva maralis de madera maciza de haya 70 x 140 cm
# medidor infantil lexie de mdf 16,2 x 158 cm
# topper freya 140 x 190 cm
# topper freya 160 x 200 cm
# topper freya 180 x 200 cm
# tapiz mural adelina smile every day blanco y mulicolor 52 x 60 cm
# tapiz mural dipsi 100% algodon multicolor let's play 52 x 60 cm
# tapiz mural nerta 100% algodon little man cave multicolor 35 x 45 cm
# tapiz mural leshy 100% algodon oh happy place multicolor 35 x 25 cm
# guirnalda con banderines nami 100% algodon organico (gots) multicolor
# baliza solar alima de acero inoxidable con acabado negro 50 cm
# guirnalda luminosa led bianca transparente 19,5 cm
# doudou yamile 100% algodon organico (gots) turquesa
# x pata cilindrica 33 cm oxidon
# modulo compo 3 plazas gris oscuro 232 cm
# modulo compo 3 plazas beige 232 cm
# modulo compo 3 plazas azul 232 cm
# brazo compo beige
# brazo compo gris claro
# brazo compo turquesa
# nordico gianela 70 x 140 cm
# mecedora marlina de borreguito blanco
# terrazzo bowl washbasin black finish //
# mecedora infantil metal blanco tela borrego blanco
# burra adelaine de madera maciza de pino natural y mdf blanco 100 x 40 cm fsc mix credit
# carrito con almacenaje bianina madera maciza de pino natural y mdf blanco fsc mix credit
# baul nunila de mdf blanco
